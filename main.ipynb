# %% [markdown]
# # Download dataset
#
# Download the dataset from [EasyGWAS](https://easygwas.ethz.ch/down/dataset/download/1/)

# %%
from zipfile import ZipFile


def extract():
    with ZipFile("AtPolyDB_(call_method_75__Horton_et_al).zip") as myzip:
        myzip.extractall()
extract()

# %%
# use plink extract
# !plink --file genotype
# Out:
# PLINK v1.90b6.26 64-bit (2 Apr 2022)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to plink.log.
# Options in effect:
#   --file genotype
#
# 7806 MB RAM detected; reserving 3903 MB for main workspace.
# .ped scan complete (for binary autoconversion)....%
# Performing single-pass .bed write (214051 variants, 1307 people).
# --file: plink.bed + plink.bim + plink.fam written.353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394%

# %%
from pandas_plink import read_plink
import pandas as pd


bim, fam, bed = read_plink("plink")
genotypes = bed.compute()
phenotypes = pd.read_csv("phenotypes.pheno", sep=" ")
# Out:
# Mapping files: 100%|██████████| 3/3 [00:00<00:00,  5.70it/s]
